# %% [markdown]
# # Small-molecule targeting of kinesin-13 KIF2C enhances double-strand break DNA repair and slows down aging

# %% [markdown]
# ## RNA-seq Analysis in Python

# %% [markdown]
# Below, I will perform RNA-seq (IonTorrent Targeted Transcriptome) analysis on HGPS fibroblasts treated with UMK57, thus reproducing in Python the analysis made in the Nature Communications paper "Small-molecule targeting of kinesin-13 KIF2C enhances double-strand break DNA repair and slows down aging".

# %% [markdown]
# ### Check Working Directory

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cdsou\\Desktop\\Bioinformatics\\Python\\hgps_ds_umk57_practise'

# %% [markdown]
# ### Import RNA-seq Data

# %% [markdown]
# Raw gene counts were obtained from the IonTorrent suite. Counts and metadata are available in the original repository for the paper:

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
np.__version__
# Out:
# '2.3.5'

# %%
raw_counts = pd.read_csv("input_data/counts_matrix.csv", sep = ",", index_col = 0)
raw_counts
# Out:
#             IonXpress_013_03042019  IonXpress_014_03042019  \
# SEC24B-AS1                       1                       1
# A1BG                             5                       2
# A1CF                             0                       0
# GGACT                            3                       2
# A2M                            161                      28
# ...                            ...                     ...
# ERCC-00112                       0                       0
# ERCC-00131                       0                       0
# ERCC-00136                       0                       0
# ERCC-00157                       0                       0
# ERCC-00171                       0                       0
#
#             IonXpress_007_21012022  IonXpress_014_21012022  \
# SEC24B-AS1                       5                       0
# A1BG                             0                       0
# A1CF                             0                       0
# ...

# %%
sample_metadata = pd.read_csv("input_data/sample_info.csv", sep = ",", index_col = 0)
sample_metadata
# Out:
#                        Individual Treatment  Disease     batch  \
# IonXpress_013_03042019   HGPS 169      DMSO     HGPS   3042019
# IonXpress_014_03042019   HGPS 169     UMK57     HGPS   3042019
# IonXpress_007_21012022   HGPS 169      DMSO     HGPS  21012022
# IonXpress_014_21012022   HGPS 169     UMK57     HGPS  21012022
# IonXpress_005_27012022   HGPS 169      DMSO     HGPS  27012022
# IonXpress_006_27012022   HGPS 169     UMK57     HGPS  27012022
# IonXpress_013_27012022   HGPS 169      DMSO     HGPS  27012022
# IonXpress_014_27012022   HGPS 169     UMK57     HGPS  27012022
# IonXpress_007_03042019        NEO      DMSO  Healthy   3042019
# IonXpress_008_03042019        NEO      DMSO  Healthy   3042019
# IonXpress_092_22082022      5y_DS      DMSO       DS  22082022
# IonXpress_096_22082022      5y_DS      DMSO       DS  22082022
# IonXpress_090_22082022     14y_DS      DMSO       DS  22082022
# IonXpress_094_22082022     14y_DS      DMSO       DS  22082022
# ...

# %% [markdown]
# Counts matrices need to show samples in rows, so we need to transpose:

# %%
raw_counts_trans = raw_counts.T
raw_counts_trans
# Out:
#                         SEC24B-AS1  A1BG  A1CF  GGACT  A2M  A2ML1  A2MP1  \
# IonXpress_013_03042019           1     5     0      3  161      0      0
# IonXpress_014_03042019           1     2     0      2   28      0      0
# IonXpress_007_21012022           5     0     0      0   64      0      0
# IonXpress_014_21012022           0     0     0      0   18      0      0
# IonXpress_005_27012022           2     2     0      3  387      0      0
# IonXpress_006_27012022           2     1     0      1   62      0      0
# IonXpress_013_27012022           2     4     0      0  303      0      0
# IonXpress_014_27012022           1     3     0      4   51      0      0
# IonXpress_007_03042019           9     0     0      1    3      0      0
# IonXpress_008_03042019           1     1     0      2    2      0      0
# IonXpress_092_22082022           6     3     0      2    3      0      0
# IonXpress_096_22082022           5     1     0      0   17      0      0
# ...

# %% [markdown]
# Check if sample names match between counts matrix and metadata:

# %%
raw_counts_trans.index == sample_metadata.index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# #### HGPS UMK57 vs DMSO

# %% [markdown]
# Raw counts are available for Young, HGPS and Down Syndrome fibroblasts. First, I will select only samples of interest (HGPS):

# %%
samples_of_interest = "HGPS"
samples_of_interest
# Out:
# 'HGPS'

# %%
sample_metadata["Disease"] == samples_of_interest
# Out:
# IonXpress_013_03042019     True
# IonXpress_014_03042019     True
# IonXpress_007_21012022     True
# IonXpress_014_21012022     True
# IonXpress_005_27012022     True
# IonXpress_006_27012022     True
# IonXpress_013_27012022     True
# IonXpress_014_27012022     True
# IonXpress_007_03042019    False
# IonXpress_008_03042019    False
# IonXpress_092_22082022    False
# IonXpress_096_22082022    False
# IonXpress_090_22082022    False
# IonXpress_094_22082022    False
# IonXpress_091_22082022    False
# IonXpress_095_22082022    False
# IonXpress_089_22082022    False
# IonXpress_093_22082022    False
# Name: Disease, dtype: bool

# %%
hgps_samples = sample_metadata.loc[sample_metadata["Disease"] == samples_of_interest]
hgps_samples
# Out:
#                        Individual Treatment Disease     batch  \
# IonXpress_013_03042019   HGPS 169      DMSO    HGPS   3042019
# IonXpress_014_03042019   HGPS 169     UMK57    HGPS   3042019
# IonXpress_007_21012022   HGPS 169      DMSO    HGPS  21012022
# IonXpress_014_21012022   HGPS 169     UMK57    HGPS  21012022
# IonXpress_005_27012022   HGPS 169      DMSO    HGPS  27012022
# IonXpress_006_27012022   HGPS 169     UMK57    HGPS  27012022
# IonXpress_013_27012022   HGPS 169      DMSO    HGPS  27012022
# IonXpress_014_27012022   HGPS 169     UMK57    HGPS  27012022
#
#                                              X        geo_sample  \
# IonXpress_013_03042019  IonXpress_013_03042019   HGPS 169_DMSO_1
# IonXpress_014_03042019  IonXpress_014_03042019  HGPS 169_UMK57_1
# IonXpress_007_21012022  IonXpress_007_21012022   HGPS 169_DMSO_2
# IonXpress_014_21012022  IonXpress_014_21012022  HGPS 169_UMK57_2
# IonXpress_005_27012022  IonXpress_005_27012022   HGPS 169_DMSO_3
# ...

# %%
hgps_samples.index
# Out:
# Index(['IonXpress_013_03042019', 'IonXpress_014_03042019',
#        'IonXpress_007_21012022', 'IonXpress_014_21012022',
#        'IonXpress_005_27012022', 'IonXpress_006_27012022',
#        'IonXpress_013_27012022', 'IonXpress_014_27012022'],
#       dtype='object')

# %%
raw_counts_trans.index.isin(hgps_samples.index)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False, False, False, False, False, False, False, False])

# %%
raw_counts_hgps = raw_counts_trans.loc[raw_counts_trans.index.isin(hgps_samples.index)]
raw_counts_hgps
# Out:
#                         SEC24B-AS1  A1BG  A1CF  GGACT  A2M  A2ML1  A2MP1  \
# IonXpress_013_03042019           1     5     0      3  161      0      0
# IonXpress_014_03042019           1     2     0      2   28      0      0
# IonXpress_007_21012022           5     0     0      0   64      0      0
# IonXpress_014_21012022           0     0     0      0   18      0      0
# IonXpress_005_27012022           2     2     0      3  387      0      0
# IonXpress_006_27012022           2     1     0      1   62      0      0
# IonXpress_013_27012022           2     4     0      0  303      0      0
# IonXpress_014_27012022           1     3     0      4   51      0      0
#
#                         A4GALT  A4GNT  AAAS  ...  ERCC-00031  ERCC-00042  \
# IonXpress_013_03042019     490      0   276  ...           0           0
# IonXpress_014_03042019     259      0   299  ...           0           0
# IonXpress_007_21012022     249      0   209  ...           0           0
# ...

# %%
raw_counts_hgps.index == hgps_samples.index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# #### Gene Filtering for DESeq2

# %% [markdown]
# Here, I will filter genes that have very low expression as recommended for DESeq2 analysis:

# %%
min_count = 5

# %%
(raw_counts_hgps > min_count).sum()
# Out:
# SEC24B-AS1    0
# A1BG          0
# A1CF          0
# GGACT         0
# A2M           8
#              ..
# ERCC-00112    0
# ERCC-00131    0
# ERCC-00136    0
# ERCC-00157    0
# ERCC-00171    0
# Length: 20812, dtype: int64

# %% [markdown]
# So, for each gene, this shows how many samples have a min. count of 5. Let's filter then:

# %%
genes_to_keep = (raw_counts_hgps > min_count).sum() >= (len(raw_counts_hgps)/2) 
genes_to_keep
# Out:
# SEC24B-AS1    False
# A1BG          False
# A1CF          False
# GGACT         False
# A2M            True
#               ...
# ERCC-00112    False
# ERCC-00131    False
# ERCC-00136    False
# ERCC-00157    False
# ERCC-00171    False
# Length: 20812, dtype: bool

# %%
raw_counts_hgps_filt = raw_counts_hgps.loc[:, genes_to_keep]
raw_counts_hgps_filt
# Out:
#                         A2M  A4GALT  AAAS  AACS  AADAT  AAGAB  AAK1  AAMP  \
# IonXpress_013_03042019  161     490   276    69     25    331    42   556
# IonXpress_014_03042019   28     259   299   113     36    317    33   429
# IonXpress_007_21012022   64     249   209   102     36    361    16   471
# IonXpress_014_21012022   18     122   144    73     20    294    12   220
# IonXpress_005_27012022  387     864   501   178     56    705    66  1288
# IonXpress_006_27012022   62     713   681   206     60    824    78  1408
# IonXpress_013_27012022  303     614   470   173     53    800    69  1013
# IonXpress_014_27012022   51     412   568   240     75    780    59   949
#
#                         AARS  AARS2  ...  ZNF564  ZNF595  ZNF720  ZNF763  \
# IonXpress_013_03042019  2102     58  ...      30      33      18      10
# IonXpress_014_03042019  1743     62  ...      19      24      14      13
# IonXpress_007_21012022  1146     23  ...      14      27      35      21
# ...

# %% [markdown]
# #### DESeq2 HGPS

# %% [markdown]
# Next, we will run DESeq2 on HGPS UMK57 vs DMSO samples:

# %%
import pickle as pkl
from pydeseq2.dds import DeseqDataSet
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats
from pydeseq2.utils import load_example_data

# %%
inference = DefaultInference(n_cpus=8)
dds_HGPS = DeseqDataSet(
    counts = raw_counts_hgps_filt,
    metadata = hgps_samples,
    design = "~Treatment",
    refit_cooks = True,
    inference = inference,
)

# %%
dds_HGPS.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.01 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 2.30 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.27 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.52 seconds.
#
# Fitting LFCs...
# ... done in 1.65 seconds.
#
# Calculating cook's distance...
# ... done in 0.01 seconds.
#
# Replacing 0 outlier genes.

# %%
deseq2_results_hgps = DeseqStats(dds_HGPS, contrast = ["Treatment", "UMK57", "DMSO"], inference = inference, cooks_filter = False, independent_filter = False)

# %%
deseq2_results_hgps.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: Treatment UMK57 vs DMSO
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M      110.647314       -2.300608  0.291172 -7.901186  2.762611e-15
# A4GALT   406.186426       -0.511991  0.202303 -2.530813  1.137984e-02
# AAAS     351.174682        0.279100  0.140804  1.982190  4.745797e-02
# AACS     134.881456        0.410881  0.235557  1.744294  8.110787e-02
# AADAT     42.313151        0.258665  0.295235  0.876132  3.809584e-01
# ...             ...             ...       ...       ...           ...
# ZNF788    46.327610        0.119647  0.275666  0.434027  6.642689e-01
# ZNF826P    6.572099        1.134823  0.904715  1.254343  2.097175e-01
# HYDIN     10.083200       -1.284100  0.631022 -2.034952  4.185575e-02
# RNF213   397.520101       -0.485771  0.192751 -2.520200  1.172882e-02
# SFMBT1    26.729863       -0.397466  0.317053 -1.253629  2.099768e-01
#
#                  padj
# ...

# %%
deseq2_results_hgps.results_df
# Out:
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M      110.647314       -2.300608  0.291172 -7.901186  2.762611e-15
# A4GALT   406.186426       -0.511991  0.202303 -2.530813  1.137984e-02
# AAAS     351.174682        0.279100  0.140804  1.982190  4.745797e-02
# AACS     134.881456        0.410881  0.235557  1.744294  8.110787e-02
# AADAT     42.313151        0.258665  0.295235  0.876132  3.809584e-01
# ...             ...             ...       ...       ...           ...
# ZNF788    46.327610        0.119647  0.275666  0.434027  6.642689e-01
# ZNF826P    6.572099        1.134823  0.904715  1.254343  2.097175e-01
# HYDIN     10.083200       -1.284100  0.631022 -2.034952  4.185575e-02
# RNF213   397.520101       -0.485771  0.192751 -2.520200  1.172882e-02
# SFMBT1    26.729863       -0.397466  0.317053 -1.253629  2.099768e-01
#
#                  padj
# A2M      1.562633e-12
# A4GALT   1.324702e-01
# AAAS     3.165673e-01
# AACS     4.135776e-01
# ...

# %%
deseq2_results_hgps.results_df.to_csv("output_data/deseq2_results_hgps.csv")

# %% [markdown]
# Let's create a volcano plot with the results. I will use the Let's Plot library, which has a similar syntax to ggplot:

# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#         <div id="V1X2p1"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.9.0/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
# ...

# %%
deseq2_results_hgps_df = deseq2_results_hgps.results_df
deseq2_results_hgps_df
# Out:
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M      110.647314       -2.300608  0.291172 -7.901186  2.762611e-15
# A4GALT   406.186426       -0.511991  0.202303 -2.530813  1.137984e-02
# AAAS     351.174682        0.279100  0.140804  1.982190  4.745797e-02
# AACS     134.881456        0.410881  0.235557  1.744294  8.110787e-02
# AADAT     42.313151        0.258665  0.295235  0.876132  3.809584e-01
# ...             ...             ...       ...       ...           ...
# ZNF788    46.327610        0.119647  0.275666  0.434027  6.642689e-01
# ZNF826P    6.572099        1.134823  0.904715  1.254343  2.097175e-01
# HYDIN     10.083200       -1.284100  0.631022 -2.034952  4.185575e-02
# RNF213   397.520101       -0.485771  0.192751 -2.520200  1.172882e-02
# SFMBT1    26.729863       -0.397466  0.317053 -1.253629  2.099768e-01
#
#                  padj
# A2M      1.562633e-12
# A4GALT   1.324702e-01
# AAAS     3.165673e-01
# AACS     4.135776e-01
# ...

# %%
deseq2_results_hgps_df["log10padj"] = -np.log10(deseq2_results_hgps_df["padj"])
deseq2_results_hgps_df
# Out:
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M      110.647314       -2.300608  0.291172 -7.901186  2.762611e-15
# A4GALT   406.186426       -0.511991  0.202303 -2.530813  1.137984e-02
# AAAS     351.174682        0.279100  0.140804  1.982190  4.745797e-02
# AACS     134.881456        0.410881  0.235557  1.744294  8.110787e-02
# AADAT     42.313151        0.258665  0.295235  0.876132  3.809584e-01
# ...             ...             ...       ...       ...           ...
# ZNF788    46.327610        0.119647  0.275666  0.434027  6.642689e-01
# ZNF826P    6.572099        1.134823  0.904715  1.254343  2.097175e-01
# HYDIN     10.083200       -1.284100  0.631022 -2.034952  4.185575e-02
# RNF213   397.520101       -0.485771  0.192751 -2.520200  1.172882e-02
# SFMBT1    26.729863       -0.397466  0.317053 -1.253629  2.099768e-01
#
#                  padj  log10padj
# A2M      1.562633e-12  11.806143
# A4GALT   1.324702e-01   0.877882
# ...

# %%
deseq2_results_hgps_df
# Out:
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M      110.647314       -2.300608  0.291172 -7.901186  2.762611e-15
# A4GALT   406.186426       -0.511991  0.202303 -2.530813  1.137984e-02
# AAAS     351.174682        0.279100  0.140804  1.982190  4.745797e-02
# AACS     134.881456        0.410881  0.235557  1.744294  8.110787e-02
# AADAT     42.313151        0.258665  0.295235  0.876132  3.809584e-01
# ...             ...             ...       ...       ...           ...
# ZNF788    46.327610        0.119647  0.275666  0.434027  6.642689e-01
# ZNF826P    6.572099        1.134823  0.904715  1.254343  2.097175e-01
# HYDIN     10.083200       -1.284100  0.631022 -2.034952  4.185575e-02
# RNF213   397.520101       -0.485771  0.192751 -2.520200  1.172882e-02
# SFMBT1    26.729863       -0.397466  0.317053 -1.253629  2.099768e-01
#
#                  padj  log10padj
# A2M      1.562633e-12  11.806143
# A4GALT   1.324702e-01   0.877882
# ...

# %%
conditions = [
    (deseq2_results_hgps_df['padj'] < 0.05) & (deseq2_results_hgps_df['log2FoldChange'] > 0),
    (deseq2_results_hgps_df['padj'] < 0.05) & (deseq2_results_hgps_df['log2FoldChange'] < 0)
]
choices = ['Up', 'Down']

deseq2_results_hgps_df['change'] = np.select(conditions, choices, default='No Change')
deseq2_results_hgps_df
# Out:
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M      110.647314       -2.300608  0.291172 -7.901186  2.762611e-15
# A4GALT   406.186426       -0.511991  0.202303 -2.530813  1.137984e-02
# AAAS     351.174682        0.279100  0.140804  1.982190  4.745797e-02
# AACS     134.881456        0.410881  0.235557  1.744294  8.110787e-02
# AADAT     42.313151        0.258665  0.295235  0.876132  3.809584e-01
# ...             ...             ...       ...       ...           ...
# ZNF788    46.327610        0.119647  0.275666  0.434027  6.642689e-01
# ZNF826P    6.572099        1.134823  0.904715  1.254343  2.097175e-01
# HYDIN     10.083200       -1.284100  0.631022 -2.034952  4.185575e-02
# RNF213   397.520101       -0.485771  0.192751 -2.520200  1.172882e-02
# SFMBT1    26.729863       -0.397466  0.317053 -1.253629  2.099768e-01
#
#                  padj  log10padj     change
# A2M      1.562633e-12  11.806143       Down
# ...

# %%
ggplot(deseq2_results_hgps_df, aes(x = "log2FoldChange", y = "log10padj")) + \
geom_point(aes(color = "change"), size = 1.5, alpha = 0.5) + \
scale_color_manual(values = ['blue', 'gray', 'red'], name = "Direction") + \
labs(x = "Log2FC", y = "-log10(padjust)") + \
theme_bw() + \
xlim(-6, 4) + \
geom_vline(xintercept = 0, linetype = "dotted") + \
geom_hline(yintercept = 1.301, linetype = "dotted")
# Out:
#    <div id="0J5GQH" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("0J5GQH");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %% [markdown]
# As in the paper, we can see that several hundred genes become differentially expressed upon UMK57 treatment.

# %% [markdown]
# ### GSEA Analysis

# %% [markdown]
# Here, I will do GSEA analysis using the Hallmark gene sets. I will use the GSEApy library:

# %%
import gseapy as gp

# %%
gp.__version__
# Out:
# '1.1.11'

# %%
hgps_ranked = deseq2_results_hgps_df.sort_values("log2FoldChange", ascending = False)
hgps_ranked
# Out:
#            baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# PKP1      16.726248        2.432611  0.487084  4.994232  5.907036e-07
# SLC6A15    8.071855        2.308497  0.712651  3.239310  1.198194e-03
# EDARADD   10.125165        2.278140  0.628841  3.622761  2.914746e-04
# MAATS1     7.197231        2.269787  0.686674  3.305478  9.481466e-04
# LIPG      22.491942        2.126384  0.404121  5.261754  1.426877e-07
# ...             ...             ...       ...       ...           ...
# TNFSF15   36.054707       -3.969356  0.544554 -7.289194  3.118151e-13
# DAB1      13.562133       -4.034040  0.671852 -6.004363  1.920850e-09
# C3         5.434669       -5.023721  1.370420 -3.665827  2.465410e-04
# PLA2G2A    8.818889       -5.089343  1.091151 -4.664197  3.098239e-06
# SNORA53  629.639863       -6.313573  1.498033 -4.214576  2.502475e-05
#
#                  padj  log10padj change
# PKP1     4.983034e-05   4.302506     Up
# SLC6A15  2.593100e-02   1.586181     Up
# ...

# %%
hgps_ranked_2 = hgps_ranked["log2FoldChange"]
hgps_ranked_2.index
# Out:
# Index(['PKP1', 'SLC6A15', 'EDARADD', 'MAATS1', 'LIPG', 'GRB14', 'TLL2', 'BMP2',
#        'PLEK2', 'LINC00161',
#        ...
#        'RSPH9', 'VTN', 'SNORA42', 'SNORA46', 'CCL13', 'TNFSF15', 'DAB1', 'C3',
#        'PLA2G2A', 'SNORA53'],
#       dtype='object', length=12444)

# %%
hgps_ranked_2.shape
# Out:
# (12444,)

# %%
HALLMARK_HGPS_UMK57 = gp.prerank(
    rnk = hgps_ranked_2,    
    gene_sets = "MSigDB_Hallmark_2020",
    method = "multilevel",            
    sample_size = 101,                
    eps = 1e-50,                     
    threads = 4,
    min_size = 5,
    max_size = 1000,
    seed = 6,
    outdir = None
)

# %%
df_HALLMARK_HGPS_UMK57 = HALLMARK_HGPS_UMK57.res2d
df_HALLMARK_HGPS_UMK57.head(10)
# Out:
#       Name                           Term        ES       NES NOM p-val  \
# 0  prerank                    E2F Targets  0.573487  2.611321       0.0
# 1  prerank                G2-M Checkpoint  0.530369  2.441196       0.0
# 2  prerank      Interferon Gamma Response -0.667943 -2.332702       0.0
# 3  prerank      Interferon Alpha Response -0.723567 -2.321659       0.0
# 4  prerank                 Myc Targets V1  0.456086  2.107545       0.0
# 5  prerank       IL-6/JAK/STAT3 Signaling -0.682969 -2.080344       0.0
# 6  prerank          Inflammatory Response -0.576022 -1.958406       0.0
# 7  prerank                   Angiogenesis  -0.67382 -1.896963       0.0
# 8  prerank                 Myc Targets V2  0.493308  1.831811       0.0
# 9  prerank  TNF-alpha Signaling via NF-kB -0.513186 -1.814134       0.0
#
#   FDR q-val FWER p-val    Tag %  Gene %  \
# 0       0.0        0.0  130/191  27.58%
# 1       0.0        0.0   87/186  18.08%
# 2       0.0        0.0   73/148  14.88%
# ...

# %%
conditions = [
    (df_HALLMARK_HGPS_UMK57['FDR q-val'] < 0.05) & (df_HALLMARK_HGPS_UMK57['NES'] > 0),
    (df_HALLMARK_HGPS_UMK57['FDR q-val'] < 0.05) & (df_HALLMARK_HGPS_UMK57['NES'] < 0)
]
choices = ['Up', 'Down']

df_HALLMARK_HGPS_UMK57['change'] = np.select(conditions, choices, default='No Change')
df_HALLMARK_HGPS_UMK57.head(10)
# Out:
#        Name                               Term        ES       NES NOM p-val  \
# 0   prerank                        E2F Targets  0.573487  2.625863       0.0
# 1   prerank                    G2-M Checkpoint  0.530369    2.4851       0.0
# 2   prerank          Interferon Alpha Response -0.723567 -2.321685       0.0
# 3   prerank          Interferon Gamma Response -0.667943 -2.321504       0.0
# 4   prerank           IL-6/JAK/STAT3 Signaling -0.682969 -2.129857       0.0
# 5   prerank                     Myc Targets V1  0.456086  2.070217       0.0
# 6   prerank              Inflammatory Response -0.576022 -1.963942       0.0
# 7   prerank                       Angiogenesis  -0.67382 -1.858903       0.0
# 8   prerank                     Myc Targets V2  0.493308  1.835113       0.0
# 9   prerank      TNF-alpha Signaling via NF-kB -0.513186  -1.82559       0.0
# 10  prerank                         Complement -0.506916 -1.762505       0.0
# ...

# %%
df_HALLMARK_HGPS_UMK57_signif = df_HALLMARK_HGPS_UMK57.loc[df_HALLMARK_HGPS_UMK57["change"].isin(["Up", "Down"])]

# %%
df_HALLMARK_HGPS_UMK57_signif = df_HALLMARK_HGPS_UMK57_signif.sort_values("NES", ascending=True)
df_HALLMARK_HGPS_UMK57_signif
# Out:
#        Name                           Term        ES       NES NOM p-val  \
# 2   prerank      Interferon Alpha Response -0.723567 -2.321685       0.0
# 3   prerank      Interferon Gamma Response -0.667943 -2.321504       0.0
# 4   prerank       IL-6/JAK/STAT3 Signaling -0.682969 -2.129857       0.0
# 6   prerank          Inflammatory Response -0.576022 -1.963942       0.0
# 7   prerank                   Angiogenesis  -0.67382 -1.858903       0.0
# 9   prerank  TNF-alpha Signaling via NF-kB -0.513186  -1.82559       0.0
# 10  prerank                     Complement -0.506916 -1.762505       0.0
# 11  prerank            Allograft Rejection -0.514102 -1.710093  0.001208
# 13  prerank                    Coagulation -0.486048 -1.581011  0.005974
# 15  prerank                        Hypoxia -0.443879 -1.539638  0.006772
# 16  prerank           Bile Acid Metabolism -0.469222 -1.518035  0.008772
# 17  prerank                      Apoptosis -0.433635 -1.507263  0.007892
# ...

# %%
df_HALLMARK_HGPS_UMK57_signif['neg_log10_FDR'] = -np.log10(
    df_HALLMARK_HGPS_UMK57_signif['FDR q-val'].replace(0, 1e-4)
)
df_HALLMARK_HGPS_UMK57_signif
# Out:
#        Name                           Term        ES       NES NOM p-val  \
# 2   prerank      Interferon Alpha Response -0.723567 -2.321685       0.0
# 3   prerank      Interferon Gamma Response -0.667943 -2.321504       0.0
# 4   prerank       IL-6/JAK/STAT3 Signaling -0.682969 -2.129857       0.0
# 6   prerank          Inflammatory Response -0.576022 -1.963942       0.0
# 7   prerank                   Angiogenesis  -0.67382 -1.858903       0.0
# 9   prerank  TNF-alpha Signaling via NF-kB -0.513186  -1.82559       0.0
# 10  prerank                     Complement -0.506916 -1.762505       0.0
# 11  prerank            Allograft Rejection -0.514102 -1.710093  0.001208
# 13  prerank                    Coagulation -0.486048 -1.581011  0.005974
# 15  prerank                        Hypoxia -0.443879 -1.539638  0.006772
# 16  prerank           Bile Acid Metabolism -0.469222 -1.518035  0.008772
# 17  prerank                      Apoptosis -0.433635 -1.507263  0.007892
# ...

# %%
df_HALLMARK_HGPS_UMK57_signif["NES_Dummy"] = 0
df_HALLMARK_HGPS_UMK57_signif
# Out:
#        Name                           Term        ES       NES NOM p-val  \
# 2   prerank      Interferon Alpha Response -0.723567 -2.321685       0.0
# 3   prerank      Interferon Gamma Response -0.667943 -2.321504       0.0
# 4   prerank       IL-6/JAK/STAT3 Signaling -0.682969 -2.129857       0.0
# 6   prerank          Inflammatory Response -0.576022 -1.963942       0.0
# 7   prerank                   Angiogenesis  -0.67382 -1.858903       0.0
# 9   prerank  TNF-alpha Signaling via NF-kB -0.513186  -1.82559       0.0
# 10  prerank                     Complement -0.506916 -1.762505       0.0
# 11  prerank            Allograft Rejection -0.514102 -1.710093  0.001208
# 13  prerank                    Coagulation -0.486048 -1.581011  0.005974
# 15  prerank                        Hypoxia -0.443879 -1.539638  0.006772
# 16  prerank           Bile Acid Metabolism -0.469222 -1.518035  0.008772
# 17  prerank                      Apoptosis -0.433635 -1.507263  0.007892
# ...

# %%
ggplot(
    df_HALLMARK_HGPS_UMK57_signif, aes(x="NES", y="Term")
) + \
geom_segment(aes(xend="NES", yend="Term", x = "NES_Dummy")) + \
geom_point(aes(fill="change", size="neg_log10_FDR"), shape=21) + \
scale_fill_manual(values=["blue", "red"], name="Direction") + \
scale_size_area(name="-log10(FDR)") + \
theme_bw() + \
scale_y_discrete(expand=(0, 1)) + \
xlim(-3, 3) + \
labs(x = "NES", y = "Gene Sets", title = "HGPS UMK57 vs DMSO", subtitle = "Hallmark Gene Sets") + \
geom_vline(xintercept=0, linetype = "dotted")
# Out:
#    <div id="7XrWZB" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("7XrWZB");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %% [markdown]
# Here, we confirm that UMK57 treatment leads to an upregulation of proliferation signatures (E2F Targets, G2M Checkpoint, Myc Targets) and downregulation of inflammnation-associated signatures (e.g., Interferon Signaling, etc.)

# %%
terms = HALLMARK_HGPS_UMK57.res2d.Term
axs = HALLMARK_HGPS_UMK57.plot(terms[[2, 3, 5, 6, 9]], show_ranking=False, legend_kws={'loc': (1.05, 0)})

# %%
df_HALLMARK_HGPS_UMK57.to_csv("output_data/df_HALLMARK_HGPS_UMK57.csv")
